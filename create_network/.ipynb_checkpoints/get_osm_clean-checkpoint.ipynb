# %%
import osmnx as ox #openstreet
import networkx as nx

import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

import geopandas as gpd
import fiona
import shapely
from shapely.geometry import box
from shapely.geometry import shape
from shapely.geometry import LineString, Point

# %%
input_path = 'input'
output_path = 'output'

# %% [markdown]
# ---------------

# %% [markdown]
# ### get graph by place

# %%
def get_entire_graph_from_place(city, buffer_distance, epsg, output_path):
    
    place_name = f'{city}, Nederland'
    graph = ox.graph_from_place(place_name, network_type='drive', buffer_dist= buffer_distance)
    fig, ax = ox.plot_graph(graph)
    
    graph_proj = ox.project_graph(graph, to_crs=epsg)
    nodes_proj, edges_proj = ox.graph_to_gdfs(graph_proj, nodes=True, edges=True)
    print("Coordinate system:", edges_proj.crs)
    
    #stringify no numerics
    nodes_proj_stringify = ox.io._stringify_nonnumeric_cols(nodes_proj)
    edges_proj_stringify  = ox.io._stringify_nonnumeric_cols(edges_proj)

    # save graph nodes and edges to disk as GeoJSON
    nodes_proj_stringify.to_file(f'{output_path}/{city}_nodes_{epsg}ww.geojson', driver='GeoJSON')
    edges_proj_stringify.to_file(f'{output_path}/{city}_edges_{epsg}ww.geojson', driver='GeoJSON')
    
    return graph_proj

# %%
#execute
get_entire_graph_from_place('Den Helder', 10000, 28992, output_path)

# %% [markdown]
# ---------------------

# %% [markdown]
# ### get graph by shape

# %%
##via hhnk gebiedgrens
hhnk_gebied_path = f'{input_path}/extend_wgs.geojson'
hhnk_gdf = gpd.read_file(hhnk_gebied_path)
hhnk_geom = hhnk_gdf.geometry[0]
hhnk_geom

# %%
#get graph from polygon
multigraph_fromosm = ox.graph_from_polygon(
    hhnk_geom,
    network_type="drive",
    simplify = True, 
    custom_filter='["highway"~"primary|secondary|tertiary|secondary_link|tertiary_link|primary_link|unclassified" ]')
type(multigraph_fromosm)
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %%
multigraph_fromosm_proj= ox.project_graph(multigraph_fromosm)

# %%
def initialize_capacity_dry_roads(MultiGraph):
    c = {}

    #basic
    for e in MultiGraph.edges(data=True):
        if e[2]['highway'] == 'tertiary':
            e[2]['capacity'] = 1000
            c[(e[0], e[1])]  = 1000
        elif e[2]['highway'] == 'secondary_link':
            e[2]['capacity'] = 1400
            c[(e[0], e[1])]  = 1400
        elif e[2]['highway'] == 'secondary':
            e[2]['capacity'] = 1400
            c[(e[0], e[1])]  = 1400
        elif e[2]['highway'] == 'primary':
            e[2]['capacity'] = 1600
            c[(e[0], e[1])]  = 1600
        elif e[2]['highway'] == 'primary_link':
            e[2]['capacity'] = 1600
            c[(e[0], e[1])]  = 1600
        else: 
            e[2]['capacity'] = 9999 

    #floodepth naar zero 
    for e in MultiGraph.edges(data=True):
        e[2]['flooddepth'] = 0
    
    return MultiGraph, c


multigraph_fromosm_proj, capacities = initialize_capacity_dry_roads(MultiGraph= multigraph_fromosm_proj)

# %%
nodes_proj, edges_proj = ox.graph_to_gdfs(multigraph_fromosm_proj, nodes=True, edges=True)
print("Coordinate system:", edges_proj.crs)

## export
#stringify no numerics
nodes_proj_stringify = ox.io._stringify_nonnumeric_cols(nodes_proj)
edges_proj_stringify  = ox.io._stringify_nonnumeric_cols(edges_proj)

# save graph nodes and edges to disk as GeoJSON
nodes_proj_stringify.to_file(f'{output_path}/_nodes_initial.geojson', driver='GeoJSON',  crs= 'epsg:32631')
edges_proj_stringify.to_file(f'{output_path}/_edges_initial.geojson', driver='GeoJSON',  crs= 'epsg:32631')
# Out:
# Coordinate system: +proj=utm +zone=31 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs

# %% [markdown]
# ### get geometrie from place

# %%
def get_roadnetwork(city, buffer_distance, epsg, output_path):
    
    place_name = f'{city}, Nederland'
    
    roadnetwork_place = ox.geometries_from_place(place_name, buffer_dist= buffer_distance, tags= {
    'highway': True, 
    'network_type': 'drive', 
    'element_type': 'way'})
    
    roadnetwork_place_proj = ox.project_graph(roadnetwork_place, to_crs=epsg)
    
    #stringify no numerics
    roadnetwork_string = ox.io._stringify_nonnumeric_cols(roadnetwork_place)

    #safe to harddisk
    roadnetwork_string.to_file(f'{output_path}/{city}_road_network.geojson', driver='GeoJSON')

# %%
# ## convert it to a geodatafram
# edges = ox.graph_to_gdfs(graph, nodes=False, edges=True)

# %%
get_roadnetwork('Den Helder', 0, 28992, output_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2352/3191441108.py in <module>
# ----> 1 get_roadnetwork('Den Helder', 0, 28992, output_path)
#
# /tmp/ipykernel_2352/1200076982.py in get_roadnetwork(city, buffer_distance, epsg, output_path)
#       8     'element_type': 'way'})
#       9
# ---> 10     roadnetwork_place_proj = ox.project_graph(roadnetwork_place, to_crs=epsg)
#      11
#      12     #stringify no numerics
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/osmnx/projection.py in project_graph(G, to_crs)
#     142     """
#     143     # STEP 1: PROJECT THE NODES
# --> 144     gdf_nodes = utils_graph.graph_to_gdfs(G, edges=False)
#     145
#     146     # create new lat/lng columns to preserve lat/lng for later reference if
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/osmnx/utils_graph.py in graph_to_gdfs(G, nodes, edges, node_geometry, fill_edge_geometry)
#      41         following normal MultiDiGraph structure.
#      42     """
# ---> 43     crs = G.graph["crs"]
#      44
#      45     if nodes:
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'GeoDataFrame' object has no attribute 'graph'

# %%
roadnetwork_place = ox.geometries_from_place()

# %%
    place_name = f'{city}, Nederland'
    
    roadnetwork_place = ox.geometries_from_place(place_name, tags= {
    'highway': True, 
    'network_type': 'drive', 
    'element_type': 'way'})

# %%
 roadnetwork_place
# Out:
#                                                                   geometry  \
# element_type osmid
# node         47637826                             POINT (4.76982 52.93572)
#              47638193                             POINT (4.73977 52.93602)
#              47641689                             POINT (4.74070 52.93847)
#              47653743                             POINT (4.73942 52.94593)
#              47670379                             POINT (4.75807 52.95695)
# ...                                                                    ...
# way          1033451869    LINESTRING (4.76640 52.95573, 4.76630 52.95576)
#              1033451870    LINESTRING (4.76643 52.95579, 4.76634 52.95581)
#              1034188588    LINESTRING (4.75961 52.96316, 4.75964 52.96308)
#              1034927675  LINESTRING (4.77817 52.96414, 4.77814 52.96416...
#              1035035646  LINESTRING (4.76099 52.95677, 4.76098 52.95682...
#
#                         traffic_calming  bus name public_transport crossing  \
# element_type osmid
# node         47637826               NaN  NaN  NaN              NaN   marked
#              47638193               NaN  NaN  NaN              NaN      NaN
#              47641689               NaN  NaN  NaN              NaN   marked
#              47653743               NaN  NaN  NaN              NaN      NaN
#              47670379               NaN  NaN  NaN              NaN      NaN
# ...                                 ...  ...  ...              ...      ...
# way          1033451869             NaN  NaN  NaN              NaN      NaN
#              1033451870             NaN  NaN  NaN              NaN      NaN
#              1034188588             NaN  NaN  NaN              NaN      NaN
#              1034927675             NaN  NaN  NaN              NaN      NaN
#              1035035646             NaN  NaN  NaN              NaN      NaN
#
#                         crossing:island          highway direction surface  \
# element_type osmid
# node         47637826               yes         crossing       NaN     NaN
#              47638193               NaN         crossing       NaN     NaN
#              47641689               NaN         crossing       NaN     NaN
#              47653743               NaN  traffic_signals       NaN     NaN
#              47670379               NaN         give_way   forward     NaN
# ...                                 ...              ...       ...     ...
# way          1033451869             NaN          footway       NaN     NaN
#              1033451870             NaN         cycleway       NaN     NaN
#              1034188588             NaN         cycleway       NaN     NaN
#              1034927675             NaN          service       NaN     NaN
#              1035035646             NaN          footway       NaN     NaN
#
#                          ... step_count cutting horse:conditional vehicle  \
# element_type osmid       ...
# node         47637826    ...        NaN     NaN               NaN     NaN
#              47638193    ...        NaN     NaN               NaN     NaN
#              47641689    ...        NaN     NaN               NaN     NaN
#              47653743    ...        NaN     NaN               NaN     NaN
#              47670379    ...        NaN     NaN               NaN     NaN
# ...                      ...        ...     ...               ...     ...
# way          1033451869  ...        NaN     NaN               NaN     NaN
#              1033451870  ...        NaN     NaN               NaN     NaN
#              1034188588  ...        NaN     NaN               NaN     NaN
#              1034927675  ...        NaN     NaN               NaN     NaN
#              1035035646  ...        NaN     NaN               NaN     NaN
#
#                         vehicle:conditional verhicle ramp:wheelchair ford  \
# element_type osmid
# node         47637826                   NaN      NaN             NaN  NaN
#              47638193                   NaN      NaN             NaN  NaN
#              47641689                   NaN      NaN             NaN  NaN
#              47653743                   NaN      NaN             NaN  NaN
#              47670379                   NaN      NaN             NaN  NaN
# ...                                     ...      ...             ...  ...
# way          1033451869                 NaN      NaN             NaN  NaN
#              1033451870                 NaN      NaN             NaN  NaN
#              1034188588                 NaN      NaN             NaN  NaN
#              1034927675                 NaN      NaN             NaN  NaN
#              1035035646                 NaN      NaN             NaN  NaN
#
#                         path area
# element_type osmid
# node         47637826    NaN  NaN
#              47638193    NaN  NaN
#              47641689    NaN  NaN
#              47653743    NaN  NaN
#              47670379    NaN  NaN
# ...                      ...  ...
# way          1033451869  NaN  NaN
#              1033451870  NaN  NaN
#              1034188588  NaN  NaN
#              1034927675  NaN  NaN
#              1035035646  NaN  NaN
#
# [6124 rows x 129 columns]
